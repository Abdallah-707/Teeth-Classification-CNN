# %% [markdown]
# ## Import Needed Libraries

# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

from sklearn.model_selection import train_test_split
import tensorflow as tf
from tensorflow import keras
from PIL import Image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D , Activation, MaxPooling2D,BatchNormalization
from tensorflow.keras.optimizers import Adamax,Adam
from tensorflow.keras.models import Sequential
from tensorflow.keras.callbacks import  EarlyStopping,ModelCheckpoint
from sklearn.metrics import confusion_matrix, classification_report
import warnings
warnings.filterwarnings('ignore')

print('models loaded')
# Out:
# models loaded

# %% [markdown]
# ## Read Training Data

# %%
data_dir='Teeth_Dataset'
target_folder='Training'
filepath=[]
labels=[]
all_folder_path = os.path.join(data_dir, target_folder)

if os.path.isdir(all_folder_path):
    filelist = os.listdir(all_folder_path)
    for f in filelist:
        fpath = os.path.join(all_folder_path, f)
        fipath=os.listdir(fpath)
        for image in fipath:
            path = os.path.join(fpath, image)
            filepath.append(path)
            labels.append(f)
f_series = pd.Series(filepath, name='filepath')
l_series = pd.Series(labels, name='labels')
train_df = pd.concat([f_series, l_series], axis=1)
train_df
# Out:
#                                           filepath labels
# 0      Teeth_Dataset\Training\CaS\a_100_0_1462.jpg    CaS
# 1      Teeth_Dataset\Training\CaS\a_100_0_4424.jpg    CaS
# 2      Teeth_Dataset\Training\CaS\a_100_0_5215.jpg    CaS
# 3      Teeth_Dataset\Training\CaS\a_100_0_5539.jpg    CaS
# 4      Teeth_Dataset\Training\CaS\a_100_0_6127.jpg    CaS
# ...                                            ...    ...
# 3082  Teeth_Dataset\Training\OT\ot_1262_0_4649.jpg     OT
# 3083  Teeth_Dataset\Training\OT\ot_1262_0_8165.jpg     OT
# 3084  Teeth_Dataset\Training\OT\ot_1262_0_8806.jpg     OT
# 3085  Teeth_Dataset\Training\OT\ot_1262_0_9432.jpg     OT
# 3086  Teeth_Dataset\Training\OT\ot_1262_0_9453.jpg     OT
#
# [3087 rows x 2 columns]

# %% [markdown]
# ## Read Validation Data

# %%
data_dir='Teeth_Dataset'
target_folder='Validation'
filepath=[]
labels=[]
all_folder_path = os.path.join(data_dir, target_folder)

if os.path.isdir(all_folder_path):
    filelist = os.listdir(all_folder_path)
    for f in filelist:
        fpath = os.path.join(all_folder_path, f)
        fipath=os.listdir(fpath)
        for image in fipath:
            path = os.path.join(fpath, image)
            filepath.append(path)
            labels.append(f)
f_series = pd.Series(filepath, name='filepath')
l_series = pd.Series(labels, name='labels')
valid_df = pd.concat([f_series, l_series], axis=1)
valid_df
# Out:
#                                             filepath labels
# 0       Teeth_Dataset\Validation\CaS\a_100_0_982.jpg    CaS
# 1      Teeth_Dataset\Validation\CaS\a_101_0_2726.jpg    CaS
# 2      Teeth_Dataset\Validation\CaS\a_101_0_5413.jpg    CaS
# 3      Teeth_Dataset\Validation\CaS\a_102_0_5905.jpg    CaS
# 4      Teeth_Dataset\Validation\CaS\a_102_0_5975.jpg    CaS
# ...                                              ...    ...
# 1023  Teeth_Dataset\Validation\OT\ot_1260_0_4990.jpg     OT
# 1024  Teeth_Dataset\Validation\OT\ot_1261_0_7691.jpg     OT
# 1025  Teeth_Dataset\Validation\OT\ot_1261_0_8294.jpg     OT
# 1026  Teeth_Dataset\Validation\OT\ot_1261_0_8460.jpg     OT
# 1027  Teeth_Dataset\Validation\OT\ot_1262_0_9721.jpg     OT
#
# [1028 rows x 2 columns]

# %% [markdown]
# ## Read Testing Data

# %%
data_dir='Teeth_Dataset'
target_folder='Testing'
filepath = []
labels = []
all_folder_path = os.path.join(data_dir, target_folder)

if os.path.isdir(all_folder_path):
    filelist = os.listdir(all_folder_path)
    for f in filelist:
        fpath = os.path.join(all_folder_path, f)
        if os.path.isdir(fpath):
            fipath = os.listdir(fpath)
            for image in fipath:
                path = os.path.join(fpath, image)
                filepath.append(path)
                labels.append(f)  
f_series = pd.Series(filepath, name='filepath')
l_series = pd.Series(labels, name='labels')
test_df = pd.concat([f_series, l_series], axis=1)
test_df
# Out:
#                                          filepath labels
# 0             Teeth_Dataset\Testing\CaS\a_100.jpg    CaS
# 1      Teeth_Dataset\Testing\CaS\a_101_0_1635.jpg    CaS
# 2      Teeth_Dataset\Testing\CaS\a_101_0_1711.jpg    CaS
# 3      Teeth_Dataset\Testing\CaS\a_101_0_4911.jpg    CaS
# 4      Teeth_Dataset\Testing\CaS\a_102_0_1227.jpg    CaS
# ...                                           ...    ...
# 1023  Teeth_Dataset\Testing\OT\ot_1260_0_1542.jpg     OT
# 1024  Teeth_Dataset\Testing\OT\ot_1261_0_1417.jpg     OT
# 1025  Teeth_Dataset\Testing\OT\ot_1261_0_1662.jpg     OT
# 1026  Teeth_Dataset\Testing\OT\ot_1262_0_4259.jpg     OT
# 1027  Teeth_Dataset\Testing\OT\ot_1262_0_4463.jpg     OT
#
# [1028 rows x 2 columns]

# %% [markdown]
# ## Visulization

# %%
train_counts = train_df['labels'].value_counts()
train_counts
# Out:
# labels
# MC     540
# OLP    540
# CaS    480
# CoS    450
# OT     393
# Gum    360
# OC     324
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

labels = train_counts.index
sizes  = train_counts.values

fig, ax = plt.subplots(figsize=(6, 6))

wedges, texts, autotexts = ax.pie(
    sizes,
    labels=labels,
    autopct="%1.1f%%",
    pctdistance=0.85,   
    startangle=90,
    wedgeprops=dict(width=0.3, edgecolor="w")  
)

centre_circle = plt.Circle((0, 0), 0.60, fc="white")
ax.add_artist(centre_circle)

ax.set_title("Training-set Class Distribution", fontsize=14)
plt.tight_layout()
plt.show()

# %%
valid_counts = valid_df['labels'].value_counts()
valid_counts
# Out:
# labels
# MC     180
# OLP    180
# CaS    160
# CoS    149
# OT     131
# Gum    120
# OC     108
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

labels = valid_counts.index
sizes  = valid_counts.values

fig, ax = plt.subplots(figsize=(6, 6))

wedges, texts, autotexts = ax.pie(
    sizes,
    labels=labels,
    autopct="%1.1f%%",
    pctdistance=0.85,   
    startangle=90,
    wedgeprops=dict(width=0.3, edgecolor="w")  
)

centre_circle = plt.Circle((0, 0), 0.60, fc="white")
ax.add_artist(centre_circle)

ax.set_title("Validation-set Class Distribution", fontsize=14)
plt.tight_layout()
plt.show()

# %%
test_counts = test_df['labels'].value_counts()
test_counts
# Out:
# labels
# MC     180
# OLP    180
# CaS    160
# CoS    149
# OT     131
# Gum    120
# OC     108
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

labels = test_counts.index
sizes  = test_counts.values

fig, ax = plt.subplots(figsize=(6, 6))

wedges, texts, autotexts = ax.pie(
    sizes,
    labels=labels,
    autopct="%1.1f%%",
    pctdistance=0.85, 
    startangle=90,
    wedgeprops=dict(width=0.3, edgecolor="w") 
)
centre_circle = plt.Circle((0, 0), 0.60, fc="white")
ax.add_artist(centre_circle)

ax.set_title("Test-set Class Distribution", fontsize=14)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Sample from Data before Augmentation

# %%
classes = train_df['labels'].unique()

g_dict = {class_name: index for index, class_name in enumerate(classes)}
plt.figure(figsize=(20, 20))
for i in range(min(16, len(train_df))):
    plt.subplot(4, 4, i + 1)
    img_path = train_df.iloc[i]['filepath']
    image = Image.open(img_path)
    image = np.array(image) / 255  
    plt.imshow(image)
    class_name = train_df.iloc[i]['labels']
    plt.title(class_name, color='black', fontsize=12)
    plt.axis('off')
plt.show()

# %%
print(train_df.shape)
print(valid_df.shape)
print(test_df.shape)
# Out:
# (3087, 2)
# (3087, 2)
# (3087, 2)

# %% [markdown]
# ## Apply Augmentation

# %%
batch_size = 64
img_size = (224, 224)
channels = 3
img_shape = (img_size[0], img_size[1], channels)
tra_gen = ImageDataGenerator(rotation_range=10,
    width_shift_range=0.1,
    height_shift_range=0.1,
    shear_range=0.1,
    zoom_range=0.1,
    horizontal_flip=True,
    fill_mode='nearest',
    brightness_range=[0.2, 1.2])
ts_gen=ImageDataGenerator()

train_gen = tra_gen.flow_from_dataframe( train_df, x_col= 'filepath', y_col= 'labels', target_size= img_size,
                                    class_mode= 'categorical',color_mode= 'rgb', shuffle= True, batch_size= batch_size)

valid_gen = ts_gen.flow_from_dataframe( valid_df, x_col= 'filepath', y_col= 'labels', target_size= img_size, 
                                    class_mode= 'categorical',color_mode= 'rgb', shuffle= True, batch_size= batch_size)
test_gen = ts_gen.flow_from_dataframe( test_df, x_col= 'filepath', y_col= 'labels', target_size= img_size, 
                                    class_mode= 'categorical',color_mode= 'rgb', shuffle= True, batch_size= batch_size)
# Out:
# Found 3087 validated image filenames belonging to 7 classes.
# Found 3087 validated image filenames belonging to 7 classes.
# Found 3087 validated image filenames belonging to 7 classes.

# %% [markdown]
# ## Sample From Data After Augmentation

# %%
g_dict = train_gen.class_indices
classes = list(g_dict.keys())
images, labels = next(train_gen)

plt.figure(figsize= (20, 20))

for i in range(16):
    plt.subplot(4, 4, i + 1)
    image = images[i] / 255
    plt.imshow(image)
    index = np.argmax(labels[i])
    class_name = classes[index]
    plt.title(class_name, color= 'black', fontsize= 12)
    plt.axis('off')
plt.show()

# %% [markdown]
# ## Build Model

# %%
base_model=keras.applications.EfficientNetB0(include_top=False,
    weights="imagenet",
    input_shape=(224,224,3))
model=Sequential([
    base_model,
    Flatten(),
    Dense(256,activation='relu')
    Dropout(0.25),
    Dense(128,activation='relu'),
    Dense(7,activation='softmax')
])
model.compile(Adamax(learning_rate= 0.0001), loss= 'categorical_crossentropy', metrics= ['accuracy'])
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ efficientnetb0 (Functional)          │ (None, 7, 7, 1280)          │       4,049,571 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 62720)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 256)                 │      16,056,576 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 256)                 │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 128)                 │          32,896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 7)                   │             903 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 20,139,946 (76.83 MB)
#  Trainable params: 20,097,923 (76.67 MB)
#  Non-trainable params: 42,023 (164.16 KB)

# %%
early_stopping = EarlyStopping(monitor='val_loss',patience=5,restore_best_weights=True)
history=model.fit(train_gen,epochs=100,validation_data=valid_gen,shuffle=False,
                  callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 164s 2s/step - accuracy: 0.3073 - loss: 1.8845 - val_accuracy: 0.3872 - val_loss: 1.6138
# Epoch 2/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 852ms/step - accuracy: 0.6299 - loss: 1.0655 - val_accuracy: 0.4951 - val_loss: 1.3532
# Epoch 3/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 848ms/step - accuracy: 0.7230 - loss: 0.8031 - val_accuracy: 0.6070 - val_loss: 1.1099
# Epoch 4/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 844ms/step - accuracy: 0.8086 - loss: 0.5800 - val_accuracy: 0.7461 - val_loss: 0.7242
# Epoch 5/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 845ms/step - accuracy: 0.8639 - loss: 0.4349 - val_accuracy: 0.8220 - val_loss: 0.5086
# Epoch 6/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 848ms/step - accuracy: 0.8815 - loss: 0.3590 - val_accuracy: 0.9086 - val_loss: 0.2985
# Epoch 7/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 839ms/step - accuracy: 0.9152 - loss: 0.2609 - val_accuracy: 0.9494 - val_loss: 0.1805
# Epoch 8/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 845ms/step - accuracy: 0.9154 - loss: 0.2457 - val_accuracy: 0.9601 - val_loss: 0.1372
# Epoch 9/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 846ms/step - accuracy: 0.9480 - loss: 0.1807 - val_accuracy: 0.9689 - val_loss: 0.1108
# Epoch 10/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 848ms/step - accuracy: 0.9470 - loss: 0.1675 - val_accuracy: 0.9767 - val_loss: 0.0871
# Epoch 11/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 845ms/step - accuracy: 0.9529 - loss: 0.1391 - val_accuracy: 0.9805 - val_loss: 0.0691
# Epoch 12/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 839ms/step - accuracy: 0.9554 - loss: 0.1311 - val_accuracy: 0.9805 - val_loss: 0.0693
# Epoch 13/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 850ms/step - accuracy: 0.9630 - loss: 0.1156 - val_accuracy: 0.9825 - val_loss: 0.0605
# Epoch 14/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 860ms/step - accuracy: 0.9694 - loss: 0.0931 - val_accuracy: 0.9864 - val_loss: 0.0509
# Epoch 15/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 851ms/step - accuracy: 0.9683 - loss: 0.0886 - val_accuracy: 0.9883 - val_loss: 0.0446
# Epoch 16/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 852ms/step - accuracy: 0.9832 - loss: 0.0699 - val_accuracy: 0.9903 - val_loss: 0.0376
# Epoch 17/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 845ms/step - accuracy: 0.9739 - loss: 0.0801 - val_accuracy: 0.9912 - val_loss: 0.0344
# Epoch 18/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 853ms/step - accuracy: 0.9806 - loss: 0.0626 - val_accuracy: 0.9932 - val_loss: 0.0301
# Epoch 19/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 847ms/step - accuracy: 0.9832 - loss: 0.0654 - val_accuracy: 0.9951 - val_loss: 0.0261
# Epoch 20/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 845ms/step - accuracy: 0.9901 - loss: 0.0438 - val_accuracy: 0.9932 - val_loss: 0.0279
# Epoch 21/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 849ms/step - accuracy: 0.9834 - loss: 0.0526 - val_accuracy: 0.9932 - val_loss: 0.0242
# Epoch 22/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 840ms/step - accuracy: 0.9819 - loss: 0.0521 - val_accuracy: 0.9961 - val_loss: 0.0205
# Epoch 23/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 845ms/step - accuracy: 0.9870 - loss: 0.0446 - val_accuracy: 0.9961 - val_loss: 0.0201
# Epoch 24/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 848ms/step - accuracy: 0.9873 - loss: 0.0383 - val_accuracy: 0.9942 - val_loss: 0.0210
# Epoch 25/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 853ms/step - accuracy: 0.9875 - loss: 0.0358 - val_accuracy: 0.9942 - val_loss: 0.0183
# Epoch 26/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 845ms/step - accuracy: 0.9866 - loss: 0.0446 - val_accuracy: 0.9932 - val_loss: 0.0193
# Epoch 27/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 852ms/step - accuracy: 0.9923 - loss: 0.0332 - val_accuracy: 0.9951 - val_loss: 0.0142
# Epoch 28/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 840ms/step - accuracy: 0.9906 - loss: 0.0324 - val_accuracy: 0.9951 - val_loss: 0.0150
# Epoch 29/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 853ms/step - accuracy: 0.9895 - loss: 0.0283 - val_accuracy: 0.9961 - val_loss: 0.0153
# Epoch 30/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 845ms/step - accuracy: 0.9896 - loss: 0.0322 - val_accuracy: 0.9951 - val_loss: 0.0138
# Epoch 31/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 853ms/step - accuracy: 0.9940 - loss: 0.0259 - val_accuracy: 0.9961 - val_loss: 0.0127
# Epoch 32/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 844ms/step - accuracy: 0.9894 - loss: 0.0295 - val_accuracy: 0.9951 - val_loss: 0.0145
# Epoch 33/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 844ms/step - accuracy: 0.9914 - loss: 0.0296 - val_accuracy: 0.9981 - val_loss: 0.0105
# Epoch 34/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 841ms/step - accuracy: 0.9910 - loss: 0.0260 - val_accuracy: 0.9981 - val_loss: 0.0114
# Epoch 35/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 854ms/step - accuracy: 0.9939 - loss: 0.0224 - val_accuracy: 0.9981 - val_loss: 0.0092
# Epoch 36/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 847ms/step - accuracy: 0.9944 - loss: 0.0228 - val_accuracy: 0.9981 - val_loss: 0.0102
# Epoch 37/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 846ms/step - accuracy: 0.9953 - loss: 0.0166 - val_accuracy: 0.9971 - val_loss: 0.0096
# Epoch 38/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 851ms/step - accuracy: 0.9911 - loss: 0.0271 - val_accuracy: 0.9971 - val_loss: 0.0110
# Epoch 39/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 42s 852ms/step - accuracy: 0.9953 - loss: 0.0146 - val_accuracy: 0.9971 - val_loss: 0.0127
# Epoch 40/100
# 49/49 ━━━━━━━━━━━━━━━━━━━━ 41s 843ms/step - accuracy: 0.9931 - loss: 0.0206 - val_accuracy: 0.9961 - val_loss: 0.0113

# %% [markdown]
# ## Compare between accuracy and Loss

# %%
tr_acc = history.history['accuracy']
tr_loss = history.history['loss']
val_acc = history.history['val_accuracy']
val_loss = history.history['val_loss']
index_loss = np.argmin(val_loss)
val_lowest = val_loss[index_loss]
index_acc = np.argmax(val_acc)
acc_highest = val_acc[index_acc]
Epochs = [i+1 for i in range(len(tr_acc))]
loss_label = f'best epoch= {str(index_loss + 1)}'
acc_label = f'best epoch= {str(index_acc + 1)}'
plt.figure(figsize= (20, 8))
plt.style.use('fivethirtyeight')
plt.subplot(1, 2, 1)
plt.plot(Epochs, tr_loss, 'r', label= 'Training loss')
plt.plot(Epochs, val_loss, 'g', label= 'Validation loss')
plt.scatter(index_loss + 1, val_lowest, s= 150, c= 'blue', label= loss_label)
plt.title('Training and Validation Loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(Epochs, tr_acc, 'r', label= 'Training Accuracy')
plt.plot(Epochs, val_acc, 'g', label= 'Validation Accuracy')
plt.scatter(index_acc + 1 , acc_highest, s= 150, c= 'blue', label= acc_label)
plt.title('Training and Validation Accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()

plt.tight_layout
plt.show()

# %% [markdown]
# ## Evalution

# %%
ts_length = len(test_df)
test_batch_size = max(sorted([ts_length // n for n in range(1, ts_length + 1) if ts_length%n == 0 and ts_length/n <= 80]))
test_steps = ts_length // test_batch_size

train_score = model.evaluate(train_gen, steps= test_steps, verbose= 1)
valid_score = model.evaluate(valid_gen, steps= test_steps, verbose= 1)
test_score = model.evaluate(test_gen, steps= test_steps, verbose= 1)

print("Train Loss: ", train_score[0])
print("Train Accuracy: ", train_score[1])
print('-' * 20)
print("Valid Loss: ", valid_score[0])
print("Valid Accuracy: ", valid_score[1])
print('-' * 20)
print("Test Loss: ", test_score[0])
print("Test Accuracy: ", test_score[1])
# Out:
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 42s 162ms/step - accuracy: 0.9978 - loss: 0.0066
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9980 - loss: 0.0092
# 257/257 ━━━━━━━━━━━━━━━━━━━━ 5s 19ms/step - accuracy: 0.9980 - loss: 0.0105
# Train Loss:  0.006441728211939335
# Train Accuracy:  0.9980563521385193
# --------------------
# Valid Loss:  0.009179011918604374
# Valid Accuracy:  0.9980545043945312
# --------------------
# Test Loss:  0.01044496614485979
# Test Accuracy:  0.9980545043945312

# %% [markdown]
# ## Confusion Matrix

# %%
labels = list(test_gen.class_indices.keys())  
num_classes = len(labels)

actual_labels = []
predicted_labels = []

for i in range(len(test_gen)):
    images, batch_labels = test_gen[i]  
    batch_preds = model.predict(images)  

    if batch_labels.ndim > 1 and batch_labels.shape[1] > 1:
        batch_labels = np.argmax(batch_labels, axis=1)
    
    batch_preds = np.argmax(batch_preds, axis=1)

    actual_labels.extend(batch_labels.tolist())
    predicted_labels.extend(batch_preds.tolist())

actual_labels = np.array(actual_labels, dtype=int)
predicted_labels = np.array(predicted_labels, dtype=int)

# Compute Confusion Matrix
cm = confusion_matrix(actual_labels, predicted_labels)

# Plot Confusion Matrix
plt.figure(figsize=(10, 5))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=labels, yticklabels=labels, linewidths=0.5)
plt.xlabel('\nPredicted Label', fontsize=13)
plt.ylabel('Actual Label\n', fontsize=13)
plt.title("Confusion Matrix", fontsize=14)
plt.show()
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 7s 17ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 5s 5s/step

# %% [markdown]
# ## Classification Report

# %%
report = classification_report(actual_labels, predicted_labels, target_names=labels)
print("Classification Report:\n")
print(report)
# Out:
# Classification Report:
#
#               precision    recall  f1-score   support
#
#          CaS       1.00      1.00      1.00       160
#          CoS       1.00      1.00      1.00       149
#          Gum       1.00      1.00      1.00       120
#           MC       1.00      0.99      0.99       180
#           OC       0.98      1.00      0.99       108
#          OLP       1.00      1.00      1.00       180
#           OT       1.00      1.00      1.00       131
#
#     accuracy                           1.00      1028
#    macro avg       1.00      1.00      1.00      1028
# weighted avg       1.00      1.00      1.00      1028

# %% [markdown]
# ## Save Model

# %%
model.save('teeth_classification.h5')
